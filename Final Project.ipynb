# %%
#Final Project
import flux as flx
import numpy as np
import matplotlib.pyplot as plt

# %%
'''Below is an example of a point charge with an origin at (1,0)'''
QQ = 2
final = flx.Field_Fun('point', 2, 2, QQ, [1, 0])
o, v = final.field()
print o, v
# Out:
# 4493775893.68 4493775893.68

# %%
final.graph_the_bitch()

# %%
'''Below is an example of an infinite plane'''
QQQ = 10
plane = flx.Field_Fun('infinite plane', 1, 1, QQQ, [0,0])
print plane.field()
# Out:
# (0, 564704533227.3062)

# %%
plane.graph_the_bitch()

# %%
'''Below is an example of an infinite wire'''
Q4 = .00000000000001
wire = flx.Field_Fun('infinite wire', 1,1,Q4,[0,1])
print wire.field()
# Out:
# (0, 0.00017975103569905446)

# %%
wire.graph_the_bitch()

# %%
'''Special note, the above graph looks weird. Not really sure why but it ouputs the right stuff and if you
look closely, the vecors point int the right direction and scale'''
